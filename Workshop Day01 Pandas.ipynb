# %%
 import numpy as np
import pandas as pd

list1=[12,34,45,5]
arr=np.array([12,34,45])
d= {'a': 12,'b':34, 'c':45}
labels=['a','b', 'c']

pd.Series(list1)

pd.Series(arr,labels)
# Out:
# a    12
# b    34
# c    45
# dtype: int64

# %%
student= {"name":["aman", "rohit", "om", "Rahul"],
          "iq":[100,200,300,400],
          "marks" : [23,4,45,65],
          "persentage": [19,34,56,56]

          }
stud_labels=["A", "B","C", "D"]
student1= pd.DataFrame(student,stud_labels)
print(student1)
# Out:
#     name   iq  marks  persentage
# A   aman  100     23          19
# B  rohit  200      4          34
# C     om  300     45          56
# D  Rahul  400     65          56

# %%
student1.head(3)
# Out:
#     name   iq  marks  persentage
# A   aman  100     23          19
# B  rohit  200      4          34
# c     om  300     45          56
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['iq'].plot(kind='hist', bins=20, title='iq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['marks'].plot(kind='hist', bins=20, title='marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['persentage'].plot(kind='hist', bins=20, title='persentage')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
student1.tail(2)
# Out:
#     name   iq  marks  persentage
# c     om  300     45          56
# D  Rahul  400     65          56

# %%
student1[['name','iq']]
# Out:
#     name   iq
# A   aman  100
# B  rohit  200
# c     om  300
# D  Rahul  400

# %%
student1['new']=student1['iq'] + student1['marks']
student1

student1['result']= student1['iq']+student1['persentage']
student1
# Out:
#     name   iq  marks  persentage  new  result
# A   aman  100     23          19  123     119
# B  rohit  200      4          34  204     234
# c     om  300     45          56  345     356
# D  Rahul  400     65          56  465     456

# %%
student1.drop('result', axis=1)
# Out:
#     name   iq  marks  persentage  new
# A   aman  100     23          19  123
# B  rohit  200      4          34  204
# c     om  300     45          56  345
# D  Rahul  400     65          56  465

# %%
student1
# Out:
#     name   iq  marks  persentage  new  result
# A   aman  100     23          19  123     119
# B  rohit  200      4          34  204     234
# c     om  300     45          56  345     356
# D  Rahul  400     65          56  465     456

# %%
student1.drop('result', axis=1, inplace=True)
student1
# Out:
#     name   iq  marks  persentage
# A   aman  100     23          19
# B  rohit  200      4          34
# c     om  300     45          56
# D  Rahul  400     65          56

# %%
student1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        4 non-null      object
#  1   iq          4 non-null      int64
#  2   marks       4 non-null      int64
#  3   persentage  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 332.0+ bytes

# %%
student1.describe()
# Out:
#                iq      marks  persentage
# count    4.000000   4.000000    4.000000
# mean   250.000000  34.250000   41.250000
# std    129.099445  26.474831   18.099263
# min    100.000000   4.000000   19.000000
# 25%    175.000000  18.250000   30.250000
# 50%    250.000000  34.000000   45.000000
# 75%    325.000000  50.000000   56.000000
# max    400.000000  65.000000   56.000000

# %%
student1.mean()
# Out:
# <ipython-input-38-d1d79c1c09a7>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   student1.mean()
# iq            250.00
# marks          34.25
# persentage     41.25
# dtype: float64

# %%
student1['marks'].value_counts()
# Out:
# 23    1
# 4     1
# 45    1
# 65    1
# Name: marks, dtype: int64

# %%
student1.loc['A']
# Out:
# name          aman
# iq             100
# marks           23
# persentage      19
# Name: A, dtype: object

# %%
student1.loc['A' :'B']
# Out:
#     name   iq  marks  persentage
# A   aman  100     23          19
# B  rohit  200      4          34

# %%
student1.loc['A':'C']
# Out:
#     name   iq  marks  persentage
# A   aman  100     23          19
# B  rohit  200      4          34
# c     om  300     45          56

# %%
student1.loc[['A','C'],['name','iq']]
# Out:
#    name   iq
# A  aman  100
# C    om  300

# %%
student1.iloc[:]
# Out:
#     name   iq  marks  persentage
# A   aman  100     23          19
# B  rohit  200      4          34
# C     om  300     45          56
# D  Rahul  400     65          56

# %%
student1.iloc[2]
# Out:
# name           om
# iq            300
# marks          45
# persentage     56
# Name: C, dtype: object

# %%
from numpy.random import randn
np.random.seed(42)

# %%
df= pd.DataFrame(randn(5,4), columns=['W','X','Y','Z'], index=['A','B', 'C','D','E'])
df
# Out:
#           W         X         Y         Z
# A  0.227460  1.307143 -1.607483  0.184634
# B  0.259883  0.781823 -1.236951 -1.320457
# C  0.521942  0.296985  0.250493  0.346448
# D -0.680025  0.232254  0.293072 -0.714351
# E  1.865775  0.473833 -1.191303  0.656554

# %%
df>0
# Out:
#        W     X      Y      Z
# A   True  True  False   True
# B   True  True  False  False
# C   True  True   True   True
# D  False  True   True  False
# E   True  True  False   True

# %%
df<0
# Out:
#        W      X      Y      Z
# A  False  False   True  False
# B  False  False   True   True
# C  False  False  False  False
# D   True  False  False   True
# E  False  False   True  False

# %%
df[df>1]
# Out:
#           W         X   Y   Z
# A       NaN  1.307143 NaN NaN
# B       NaN       NaN NaN NaN
# C       NaN       NaN NaN NaN
# D       NaN       NaN NaN NaN
# E  1.865775       NaN NaN NaN

# %%
df[df<1]
# Out:
#           W         X         Y         Z
# A  0.227460       NaN -1.607483  0.184634
# B  0.259883  0.781823 -1.236951 -1.320457
# C  0.521942  0.296985  0.250493  0.346448
# D -0.680025  0.232254  0.293072 -0.714351
# E       NaN  0.473833 -1.191303  0.656554

# %%
df[df>1].isnull().sum()
# Out:
# W    4
# X    4
# Y    5
# Z    5
# dtype: int64

# %%
new_df= df[df<0]
new_df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [A, B, C, D, E]

# %%
new_df.fillna(644)
# Out:
#             W      X           Y           Z
# A  644.000000  644.0   -1.607483  644.000000
# B  644.000000  644.0   -1.236951   -1.320457
# C  644.000000  644.0  644.000000  644.000000
# D   -0.680025  644.0  644.000000   -0.714351
# E  644.000000  644.0   -1.191303  644.000000
